# %% [markdown]
# #### TELECOM CUSTOMER CHURN : DATA 428 PROJECT
# # 2. Descriptive Analysis and Data Manipulation
#
# ### GENERAL NOTES ABOUT THE DATA AND JUPYTER NOTEBOOKS USED IN THE PROJECT
#
# - The ‘Telecom Customer’ dataset contains data for 100,000 customers with 99 variables collected
# over five years (max months of customer is 61).
# - It has been downloaded from ‘https://www.kaggle.com/abhinav89/telecom-customer’.
# - Original file name is "Telecom Customer.csv" - contains difficult to decipher column names.
#
# - There are a total of five Jupyter Notebooks for ease of keeping the different approaches seperate and allow room for explorations within each approach
# - Notebook No 1   : Exploratory Analysis
# - Notebook No 2   : Descriptive Analysis and DATA MANIPULATION (Flow for Imputation & Dummy Variables)
# - Notebook No 3   : Approach - 1 for Model Building (using Log & Yeo-Johnson Transformation)
# - Notebook No 3(B): To create and save Yeo-Johnson transformed data. Kept separate as done on another machine and bring in the data. (PowerTransformer is only available in versions 0.20.0 of Sci-Kit Learn)
# - Notebook No 4   : Approach - 2 for Model Building using the 'Pipeline' method, based on log transformed data. The notebook has an option of choosing Yeo-Johnson data, but for ready reference, Notebbok 4(B) was made.
# - Notebook No 4(B): Approach - 2 with Yeo_Johnson transformed data.(Notebook is same as No. 4.
# - Notebook No 5   : testing the effects of reduced features based on CONTINUITY FACTOR. A separate flow to test the effects using best Random Forest and ADA Boost models.
#
# - Jotinder S Sudan, 15 March 2019, University of Canterbury, Christchurch
#
# ### This Notebook :  No. 2
#
# - Dropping some redundant columns and outliers (only one observation)
# - Descriptive Analysis - examining 95th & 99th quantiles with respect to extremely high values.
# - Data Manipulation : Preparing different versions of the dataset (all were not used ahead)
#
#     - v1 : all blanks removed : Later, the models did not give satisfactory results on 26,000 observations.
#
#     - v2 : all blanks removed after removing redundant columns and outliers (results - same as above)
#
#     - v3 :
#          - categories with poor representation (less than 5%), clubbed into 'others'.
#          - 'U' values - treated as 'missing value'. dropped in case higher in volume or imputed with mode
#
#     - v4 : Creating a dataset with extreme high values (beyond 5xIQR) by 99th quantile (Flow created - NOT used)

# %%
import pandas as pd
import numpy as np
import scipy as sp 
import scipy.stats as sps
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Using dataset with better column names

data = pd.read_csv("telecom_data_better_colnames.csv")

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.shape
# Out:
# (100000, 100)

# %%
# Checking the data types
#data.dtypes

# %% [markdown]
# ## Data Wrangling - following issues to be addressed
#     - 'geographic_area' : names can be made better to avoid errors (learnt after making mistakes initially)
#     - drop rows with outliers
#     - drop columns with very high 'nan' / blanks
#     - drop columns like 'child_between_0_to_2_years_in_house'

# %%
data["geogrpahic_area"].unique()
# Out:
# array(['NORTHWEST/ROCKY MOUNTAIN AREA', 'CHICAGO AREA',
#        'GREAT LAKES AREA', 'NEW ENGLAND AREA', 'DALLAS AREA',
#        'CENTRAL/SOUTH TEXAS AREA', 'TENNESSEE AREA', 'MIDWEST AREA',
#        'PHILADELPHIA AREA', 'OHIO AREA', 'HOUSTON AREA', 'SOUTHWEST AREA',
#        'NEW YORK CITY AREA', 'ATLANTIC SOUTH AREA', 'SOUTH FLORIDA AREA',
#        'CALIFORNIA NORTH AREA', 'DC/MARYLAND/VIRGINIA AREA',
#        'NORTH FLORIDA AREA', nan, 'LOS ANGELES AREA'], dtype=object)

# %%
geo_area = []
for i in range(len(data)):
    item = data["geogrpahic_area"][i]
    #print(item)
    if type(item) is float:
        geo_area.append(item)
        #print(item)
    else:
        name = item.replace(' ', '_')
        name = name.replace('/', '_')
        geo_area.append(name)

# %%
data.drop("geogrpahic_area", inplace=True, axis=1)

# %%
data["geogrpahic_area"] = geo_area

# %%
data["geogrpahic_area"].unique()
# Out:
# array(['NORTHWEST_ROCKY_MOUNTAIN_AREA', 'CHICAGO_AREA',
#        'GREAT_LAKES_AREA', 'NEW_ENGLAND_AREA', 'DALLAS_AREA',
#        'CENTRAL_SOUTH_TEXAS_AREA', 'TENNESSEE_AREA', 'MIDWEST_AREA',
#        'PHILADELPHIA_AREA', 'OHIO_AREA', 'HOUSTON_AREA', 'SOUTHWEST_AREA',
#        'NEW_YORK_CITY_AREA', 'ATLANTIC_SOUTH_AREA', 'SOUTH_FLORIDA_AREA',
#        'CALIFORNIA_NORTH_AREA', 'DC_MARYLAND_VIRGINIA_AREA',
#        'NORTH_FLORIDA_AREA', nan, 'LOS_ANGELES_AREA'], dtype=object)

# %%
data.shape
# Out:
# (100000, 100)

# %% [markdown]
# ### Creating a dataset by deleting all 'nan' / 'blanks'  --> original_data_without_NA.csv

# %%
original_data_without_NA = data.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
original_data_without_NA = original_data_without_NA.reset_index()
original_data_without_NA.drop('index', axis = 1, inplace=True)

# %%
original_data_without_NA.shape
# Out:
# (26704, 100)

# %%
# Saving to a file

#original_data_without_NA.to_csv('original_data_without_NA.csv')

# %% [markdown]
# #### no_of_unique_subscribers_in_the_house
#     - This feature has numeric discrete values and some outliers like 196 unique users in a house.
#     - It's either a wrong entry or a 'close user group' (CUG) scenario of an organisation.
#     - Hence, dropping any entry with more than 20 subscribers in the house (making concessions for a hostel)

# %%
data['no_of_unique_subscribers_in_the_house'].unique()
# Out:
# array([  2,   1,   3,   5,   4,   6,   7,   9,   8,  12,  11,  10,  13,
#         18, 196], dtype=int64)

# %%
for i in range(len(data)): 
    
    value = data['no_of_unique_subscribers_in_the_house'][i]
       
    if value > 20:
        data.drop(data.index[i], inplace = True)   
data = data.reset_index()
data.drop('index', axis = 1, inplace=True)

#         no_of_unique_subscribers.append('low')
#     elif value > 2 and value < 7:
#         no_of_unique_subscribers.append('medium')
#     else:
#         no_of_unique_subscribers.append('high')

# %%
for i in range(len(data)): 
    
    value_2 = data['no_of_active_subscribers_in_house'][i]
       
    if value_2 > 20:
        data.drop(data.index[i], inplace = True)    
        
data = data.reset_index()
data.drop('index', axis = 1, inplace=True)

# %%
data.shape
# Out:
# (99999, 100)

# %% [markdown]
# ### Dropping features with large missing values
#     - 'known_no_of_vehicles' - 49.3% values missing (refer the data exploration notebook)

# %%
data.drop('known_no_of_vehicles', inplace=True, axis = 1)

# %%
data.drop('cust_id', inplace=True, axis = 1)

# %%
data.shape
# Out:
# (99999, 98)

# %% [markdown]
# ### FEATURES WITH 'U'  : Assuming 'U' to be 'Unknown' or 'Missing Value'
#
#     - new_cell_phone_user : 66.9% 'U' values, which are as good as missing values
#     - dualband :  "Y", "N", "T", "U".  Where 'U' is only 0.02%

# %%
data.new_cell_phone_user.value_counts()
# Out:
# U    66913
# Y    19301
# N    13785
# Name: new_cell_phone_user, dtype: int64

# %%
data.drop('new_cell_phone_user', inplace=True, axis = 1)

# %%
# Need to decide - what to do with 'U'
data.dualband.value_counts()
# Out:
# Y    72264
# N    23196
# T     4316
# U      222
# Name: dualband, dtype: int64

# %%
data['dualband'] = data['dualband'].str.replace('U','Y')

# %%
# need to decide what to do with 'UNKW'
data.handset_web_capability.value_counts()
# Out:
# WCMB    75732
# WC      13843
# UNKW      235
# Name: handset_web_capability, dtype: int64

# %%
data['handset_web_capability'] = data['handset_web_capability'].str.replace('UNKW', 'WCMB')

# %%
data.handset_web_capability.value_counts()
# Out:
# WCMB    75967
# WC      13843
# Name: handset_web_capability, dtype: int64

# %%
# Leaving 'U' as such because no information is available about the categories.
data.marital_status.value_counts()
# Out:
# U    37332
# M    31052
# S    17627
# B     7116
# A     5140
# Name: marital_status, dtype: int64

# %% [markdown]
# ### Dropping five columns of 'children in house' as data very sparse and not clear

# %%
list_of_children = ['child_0_to_2_yrs_in_house', 'child_3_to_5_yrs_in_house',
                   'child_6_to_10_yrs_in_house', 'child_11_to_15_yrs_in_house',
                   'child_16_to_17_yrs_in_house']

# %%
#redundant_unknown_features = ["truck_indicator", "rv_indicator", "foreign_travel_dummy_variable", "infobase_match"]

# %%
def drop_feature(drop_list):
    for feature in drop_list:
        data.drop(feature, inplace=True, axis = 1)

# %%
drop_feature(list_of_children)

# %%
#drop_feature(redundant_unknown_features)

# %%
data.shape
# Out:
# (99999, 92)

# %% [markdown]
# ### Now that we have removed some redundant columns, lets remove all 'nan' and create another dataset for analysis - dataset_without_NA_2.csv

# %%
dataset_without_NA_2 = data.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
dataset_without_NA_2 = dataset_without_NA_2.reset_index()
dataset_without_NA_2.drop('index', axis = 1, inplace=True)

# %%
dataset_without_NA_2.shape
# Out:
# (36132, 92)

# %%
# Saving to a file

#dataset_without_NA_2.to_csv("dataset_without_NA_2.csv")

# %% [markdown]
# ### Moving towards Separating columns which appear numeric (continuous), but are actually factors or discrete numbers

# %%
numeric_df = data.corr()

# %%
list_numeric_cols = list(numeric_df.columns)
data[list_numeric_cols].describe().T
# Out:
#                                                       count         mean  \
# avg_mthly_rev                                       99642.0    58.719894
# avg_no_of_mthly_mins                                99642.0   513.565091
# avg_total_mthly_recurring_charge                    99642.0    46.178746
# avg_no_of_directory_assisted_calls                  99642.0     0.888837
# avg_overage_mins                                    99642.0    41.072659
# avg_overage_rev                                     99642.0    13.559696
# avg_rev_of_voice_overage                            99642.0    13.295195
# avg_rev_of_data_overage                             99642.0     0.261320
# avg_no_of_roaming_calls                             99642.0     1.286418
# percntg_change_in_mthly_mins_vs_previous_three_...  99108.0   -13.933959
# percntg_change_in_mthly_rev_vs_previous_three_m...  99108.0    -1.021082
# avg_no_of_dropped_voice_calls                       99999.0     5.955145
# avg_no_of_dropped_data_calls                        99999.0     0.040520
# avg_no_of_blocked_voice_calls                       99999.0     4.022957
# avg_no_of_blocked_data_calls                        99999.0     0.025777
# avg_no_of_unans_voice_calls                         99999.0    27.785183
# avg_no_of_unans_data_calls                          99999.0     0.029810
# avg_no_of_attempted_voice_calls_placed              99999.0   144.883125
# avg_no_of_attempted_data_calls_placed               99999.0     0.870557
# avg_no_of_received_voice_calls                      99999.0    55.085703
# avg_no_of_recieved_sms                              99999.0     0.047590
# avg_no_of_completed_voice_calls                     99999.0   108.893624
# avg_no_of_completed_data_calls                      99999.0     0.774449
# avg_no_of_cust_care_calls                           99999.0     1.790856
# avg_rounded_mins_of_cust_care_calls                 99999.0     4.666927
# avg_unrounded_mins_of_cust_care_calls               99999.0     3.683365
# avg_no_of_inbound_calls_less_than_one_min           99999.0    29.766848
# avg_no_of_three_way_calls                           99999.0     0.284723
# avg_unrounded_mins_of_completed_voice_calls         99999.0   227.765797
# avg_unrounded_mins_of_completed_data_calls          99999.0     1.844054
# ...                                                     ...          ...
# avg_no_of_call_waiting_calls                        99999.0     1.782946
# churn                                               99999.0     0.495615
# total_no_of_months_in_service                       99999.0    18.834038
# no_of_unique_subscribers_in_the_house               99999.0     1.546195
# no_of_active_subscribers_in_house                   99999.0     1.358444
# total_no_of_calls_over_the_life_of_the_cust         99999.0  2877.159932
# total_mins_over_the_life_of_the_cust                99999.0  7648.401807
# total_rev                                           99999.0  1031.925036
# billing_adjusted_total_rev_over_the_life_of_the...  99999.0   960.111883
# billing_adjusted_total_mins_over_the_life_of_th...  99999.0  7546.351652
# billing_adjusted_total_no_of_calls_over_the_lif...  99999.0  2836.384514
# avg_mthly_rev_over_the_life_of_the_cust             99999.0    57.913699
# avg_mthly_mins_over_the_life_of_the_cust            99999.0   483.728367
# avg_mthly_no_of_calls_over_the_life_of_the_cust     99999.0   173.555414
# avg_mthly_mins_over_the_previous_three_months       99999.0   519.646406
# avg_mthly_no_of_calls_over_the_previous_three_m...  99999.0   180.339123
# avg_mthly_rev_over_the_previous_three_months        99999.0    59.193242
# avg_mthly_mins_over_the_previous_six_months         97160.0   509.639368
# avg_mthly_no_of_calls_over_the_previous_six_months  97160.0   178.366828
# avg_mthly_rev_over_the_previous_six_months          97160.0    58.683522
# current_handset_price                               99152.0   101.875479
# no_of_handsets_issued                               99998.0     1.787126
# no_of_models_issued                                 99998.0     1.545831
# truck_indicator                                     98267.0     0.188822
# rv_indicator                                        98267.0     0.082581
# length_of_residence                                 69810.0     6.177238
# no_of_adults_in_house                               76981.0     2.530326
# estimated_income                                    74564.0     5.783112
# foreign_travel_dummy_variable                       98267.0     0.057975
# no_of_days_of_current_equipment                     99997.0   391.932238
#
#                                                             std          min  \
# avg_mthly_rev                                         46.291901    -6.167500
# avg_no_of_mthly_mins                                 525.168255     0.000000
# avg_total_mthly_recurring_charge                      23.623288   -26.915000
# avg_no_of_directory_assisted_calls                     2.177628     0.000000
# avg_overage_mins                                      97.296552     0.000000
# avg_overage_rev                                       30.501008     0.000000
# avg_rev_of_voice_overage                              30.056211     0.000000
# avg_rev_of_data_overage                                3.126547     0.000000
# avg_no_of_roaming_calls                               14.711447     0.000000
# percntg_change_in_mthly_mins_vs_previous_three_...   276.088898 -3875.000000
# percntg_change_in_mthly_rev_vs_previous_three_m...    50.363463 -1107.740000
# avg_no_of_dropped_voice_calls                          8.954740     0.000000
# avg_no_of_dropped_data_calls                           0.877141     0.000000
# avg_no_of_blocked_voice_calls                         10.672247     0.000000
# avg_no_of_blocked_data_calls                           1.490262     0.000000
# avg_no_of_unans_voice_calls                           38.358825     0.000000
# avg_no_of_unans_data_calls                             0.496973     0.000000
# avg_no_of_attempted_voice_calls_placed               158.267839     0.000000
# avg_no_of_attempted_data_calls_placed                  9.053946     0.000000
# avg_no_of_received_voice_calls                        86.841458     0.000000
# avg_no_of_recieved_sms                                 2.127433     0.000000
# avg_no_of_completed_voice_calls                      118.580172     0.000000
# avg_no_of_completed_data_calls                         8.129884     0.000000
# avg_no_of_cust_care_calls                              5.315594     0.000000
# avg_rounded_mins_of_cust_care_calls                   12.762008     0.000000
# avg_unrounded_mins_of_cust_care_calls                 10.540028     0.000000
# avg_no_of_inbound_calls_less_than_one_min             55.833953     0.000000
# avg_no_of_three_way_calls                              1.092106     0.000000
# avg_unrounded_mins_of_completed_voice_calls          264.404235     0.000000
# avg_unrounded_mins_of_completed_data_calls            23.733344     0.000000
# ...                                                         ...          ...
# avg_no_of_call_waiting_calls                           5.353977     0.000000
# churn                                                  0.499983     0.000000
# total_no_of_months_in_service                          9.655830     6.000000
# no_of_unique_subscribers_in_the_house                  0.882077     1.000000
# no_of_active_subscribers_in_house                      0.634892     0.000000
# total_no_of_calls_over_the_life_of_the_cust         3790.878155     0.000000
# total_mins_over_the_life_of_the_cust                8666.593307     0.000000
# total_rev                                            852.911776     3.650000
# billing_adjusted_total_rev_over_the_life_of_the...   840.175009     2.400000
# billing_adjusted_total_mins_over_the_life_of_th...  8594.924760     0.000000
# billing_adjusted_total_no_of_calls_over_the_lif...  3756.528545     0.000000
# avg_mthly_rev_over_the_life_of_the_cust               36.161449     0.480000
# avg_mthly_mins_over_the_life_of_the_cust             438.487005     0.000000
# avg_mthly_no_of_calls_over_the_life_of_the_cust      167.825170     0.000000
# avg_mthly_mins_over_the_previous_three_months        533.634211     0.000000
# avg_mthly_no_of_calls_over_the_previous_three_m...   192.725955     0.000000
# avg_mthly_rev_over_the_previous_three_months          46.695654     1.000000
# avg_mthly_mins_over_the_previous_six_months          496.663763     0.000000
# avg_mthly_no_of_calls_over_the_previous_six_months   182.724763     0.000000
# avg_mthly_rev_over_the_previous_six_months            40.758776    -2.000000
# current_handset_price                                 61.005913     9.989998
# no_of_handsets_issued                                  1.313981     1.000000
# no_of_models_issued                                    0.898398     1.000000
# truck_indicator                                        0.391369     0.000000
# rv_indicator                                           0.275249     0.000000
# length_of_residence                                    4.735267     0.000000
# no_of_adults_in_house                                  1.452819     1.000000
# estimated_income                                       2.182132     1.000000
# foreign_travel_dummy_variable                          0.233697     0.000000
# no_of_days_of_current_equipment                      256.484711    -5.000000
#
#                                                             25%          50%  \
# avg_mthly_rev                                         33.260000    48.195000
# avg_no_of_mthly_mins                                 150.750000   355.625000
# avg_total_mthly_recurring_charge                      30.000000    44.990000
# avg_no_of_directory_assisted_calls                     0.000000     0.247500
# avg_overage_mins                                       0.000000     2.750000
# avg_overage_rev                                        0.000000     1.000000
# avg_rev_of_voice_overage                               0.000000     0.682500
# avg_rev_of_data_overage                                0.000000     0.000000
# avg_no_of_roaming_calls                                0.000000     0.000000
# percntg_change_in_mthly_mins_vs_previous_three_...   -87.000000    -6.250000
# percntg_change_in_mthly_rev_vs_previous_three_m...    -7.365625    -0.315000
# avg_no_of_dropped_voice_calls                          0.666667     3.000000
# avg_no_of_dropped_data_calls                           0.000000     0.000000
# avg_no_of_blocked_voice_calls                          0.000000     1.000000
# avg_no_of_blocked_data_calls                           0.000000     0.000000
# avg_no_of_unans_voice_calls                            5.000000    16.000000
# avg_no_of_unans_data_calls                             0.000000     0.000000
# avg_no_of_attempted_voice_calls_placed                38.333333   100.333333
# avg_no_of_attempted_data_calls_placed                  0.000000     0.000000
# avg_no_of_received_voice_calls                         5.333333    26.666667
# avg_no_of_recieved_sms                                 0.000000     0.000000
# avg_no_of_completed_voice_calls                       28.666667    75.666667
# avg_no_of_completed_data_calls                         0.000000     0.000000
# avg_no_of_cust_care_calls                              0.000000     0.000000
# avg_rounded_mins_of_cust_care_calls                    0.000000     0.000000
# avg_unrounded_mins_of_cust_care_calls                  0.000000     0.000000
# avg_no_of_inbound_calls_less_than_one_min              2.666667    12.333333
# avg_no_of_three_way_calls                              0.000000     0.000000
# avg_unrounded_mins_of_completed_voice_calls           49.053333   146.203333
# avg_unrounded_mins_of_completed_data_calls             0.000000     0.000000
# ...                                                         ...          ...
# avg_no_of_call_waiting_calls                           0.000000     0.333333
# churn                                                  0.000000     0.000000
# total_no_of_months_in_service                         11.000000    16.000000
# no_of_unique_subscribers_in_the_house                  1.000000     1.000000
# no_of_active_subscribers_in_house                      1.000000     1.000000
# total_no_of_calls_over_the_life_of_the_cust          889.000000  1822.000000
# total_mins_over_the_life_of_the_cust                2529.000000  5192.000000
# total_rev                                            518.980000   804.520000
# billing_adjusted_total_rev_over_the_life_of_the...   452.180000   737.760000
# billing_adjusted_total_mins_over_the_life_of_th...  2474.000000  5103.000000
# billing_adjusted_total_no_of_calls_over_the_lif...   868.000000  1789.000000
# avg_mthly_rev_over_the_life_of_the_cust               35.370000    49.890000
# avg_mthly_mins_over_the_life_of_the_cust             176.140000   360.190000
# avg_mthly_no_of_calls_over_the_life_of_the_cust       64.090000   127.500000
# avg_mthly_mins_over_the_previous_three_months        152.000000   358.000000
# avg_mthly_no_of_calls_over_the_previous_three_m...    55.000000   125.000000
# avg_mthly_rev_over_the_previous_three_months          33.000000    48.000000
# avg_mthly_mins_over_the_previous_six_months          163.000000   363.000000
# avg_mthly_no_of_calls_over_the_previous_six_months    59.000000   127.000000
# avg_mthly_rev_over_the_previous_six_months            34.000000    50.000000
# current_handset_price                                 29.989990    99.989990
# no_of_handsets_issued                                  1.000000     1.000000
# no_of_models_issued                                    1.000000     1.000000
# truck_indicator                                        0.000000     0.000000
# rv_indicator                                           0.000000     0.000000
# length_of_residence                                    2.000000     5.000000
# no_of_adults_in_house                                  1.000000     2.000000
# estimated_income                                       4.000000     6.000000
# foreign_travel_dummy_variable                          0.000000     0.000000
# no_of_days_of_current_equipment                      212.000000   342.000000
#
#                                                             75%            max
# avg_mthly_rev                                         70.750000    3843.262500
# avg_no_of_mthly_mins                                 703.000000   12206.750000
# avg_total_mthly_recurring_charge                      59.990000     409.990000
# avg_no_of_directory_assisted_calls                     0.990000     159.390000
# avg_overage_mins                                      42.000000    4320.750000
# avg_overage_rev                                       14.437500    1102.400000
# avg_rev_of_voice_overage                              14.025000     896.087500
# avg_rev_of_data_overage                                0.000000     423.540000
# avg_no_of_roaming_calls                                0.235000    3685.200000
# percntg_change_in_mthly_mins_vs_previous_three_...    63.000000   31219.250000
# percntg_change_in_mthly_rev_vs_previous_three_m...     1.642500    9963.657500
# avg_no_of_dropped_voice_calls                          7.666667     232.666667
# avg_no_of_dropped_data_calls                           0.000000     207.333333
# avg_no_of_blocked_voice_calls                          3.666667     385.333333
# avg_no_of_blocked_data_calls                           0.000000     413.333333
# avg_no_of_unans_voice_calls                           36.000000     848.666667
# avg_no_of_unans_data_calls                             0.000000      81.666667
# avg_no_of_attempted_voice_calls_placed               198.666667    2289.000000
# avg_no_of_attempted_data_calls_placed                  0.000000     733.666667
# avg_no_of_received_voice_calls                        71.333333    3369.333333
# avg_no_of_recieved_sms                                 0.000000     517.333333
# avg_no_of_completed_voice_calls                      149.666667    1894.333333
# avg_no_of_completed_data_calls                         0.000000     559.333333
# avg_no_of_cust_care_calls                              1.666667     675.333333
# avg_rounded_mins_of_cust_care_calls                    4.000000     861.333333
# avg_unrounded_mins_of_cust_care_calls                  2.873333     602.950000
# avg_no_of_inbound_calls_less_than_one_min             35.666667    3086.666667
# avg_no_of_three_way_calls                              0.333333      66.000000
# avg_unrounded_mins_of_completed_voice_calls          309.478333    4514.453333
# avg_unrounded_mins_of_completed_data_calls             0.000000    3032.050000
# ...                                                         ...            ...
# avg_no_of_call_waiting_calls                           1.333333     212.666667
# churn                                                  1.000000       1.000000
# total_no_of_months_in_service                         24.000000      61.000000
# no_of_unique_subscribers_in_the_house                  2.000000      18.000000
# no_of_active_subscribers_in_house                      2.000000      11.000000
# total_no_of_calls_over_the_life_of_the_cust         3492.000000   98874.000000
# total_mins_over_the_life_of_the_cust                9776.000000  233419.096700
# total_rev                                           1263.775000   27321.500000
# billing_adjusted_total_rev_over_the_life_of_the...  1188.180000   27071.300000
# billing_adjusted_total_mins_over_the_life_of_th...  9661.000000  232855.100000
# billing_adjusted_total_no_of_calls_over_the_lif...  3442.000000   98705.000000
# avg_mthly_rev_over_the_life_of_the_cust               69.480000     924.270000
# avg_mthly_mins_over_the_life_of_the_cust             655.670000    7040.130000
# avg_mthly_no_of_calls_over_the_life_of_the_cust      228.570000    3017.110000
# avg_mthly_mins_over_the_previous_three_months        711.000000    7716.000000
# avg_mthly_no_of_calls_over_the_previous_three_m...   240.000000    3909.000000
# avg_mthly_rev_over_the_previous_three_months          71.000000    1593.000000
# avg_mthly_mins_over_the_previous_six_months          698.000000    7217.000000
# avg_mthly_no_of_calls_over_the_previous_six_months   237.000000    3256.000000
# avg_mthly_rev_over_the_previous_six_months            71.000000     866.000000
# current_handset_price                                149.989990     499.989990
# no_of_handsets_issued                                  2.000000      28.000000
# no_of_models_issued                                    2.000000      16.000000
# truck_indicator                                        0.000000       1.000000
# rv_indicator                                           0.000000       1.000000
# length_of_residence                                    9.000000      15.000000
# no_of_adults_in_house                                  3.000000       6.000000
# estimated_income                                       7.000000       9.000000
# foreign_travel_dummy_variable                          0.000000       1.000000
# no_of_days_of_current_equipment                      530.000000    1823.000000
#
# [77 rows x 8 columns]

# %% [markdown]
# ### Complete List of numeric features which are not continuous
#
#     - List used for imputing with 'mode' for these features

# %%
list_of_numeric_factors = ["no_of_unique_subscribers_in_the_house",
                           "no_of_active_subscribers_in_house",
                           "no_of_handsets_issued",
                           "no_of_models_issued",
                           "no_of_adults_in_house",  
                           "estimated_income",
                           "length_of_residence", 
                           "truck_indicator",
                           "rv_indicator",
                           "foreign_travel_dummy_variable"]

# %%
numeric_features_set = set(list_numeric_cols) - set(list_of_numeric_factors)
numeric_features = list(numeric_features_set)
len(numeric_features)
# Out:
# 67

# %%
categorical_features_set = set(list(data.columns)) - set(list_numeric_cols)
categorical_features = list(categorical_features_set)
len(categorical_features)
# Out:
# 15

# %%
cat_required = ["AA", "A", "BA", "CA", "EA"]
cat_with_others = []

for i in range(len(data)):
    cat = data.credit_class_code[i]
    
    if cat in cat_required:
        cat_with_others.append(cat)
        
    if cat not in cat_required:
        cat_with_others.append("others")

# %%
data.credit_class_code = cat_with_others

# %%
ethnicity_code = []
ethnicity_code_required = ["X", "P", "M", "R", "D", "B", "F"]

for i in range(len(data)):
    cat = data.ethnicity_roll_to_up_code[i]
    
    if cat in ethnicity_code_required:
        ethnicity_code.append("others")
        
    if cat not in ethnicity_code_required:
        ethnicity_code.append(cat)

# %%
data['ethnicity_roll_to_up_code'] = ethnicity_code

# %%
data['ethnicity_roll_to_up_code'].unique()
# Out:
# array(['N', 'Z', 'U', 'I', 'S', 'others', 'J', 'H', 'G', 'O', nan, 'C'],
#       dtype=object)

# %%
data.credit_class_code.unique()
# Out:
# array(['A', 'EA', 'others', 'BA', 'CA', 'AA'], dtype=object)

# %%
data.shape
# Out:
# (99999, 92)

# %%
data.to_csv('data_before_log.csv')

# %% [markdown]
# ## MANIPULATING NUMERIC FEATURES - Looking at Outliers, using IQR and 99th quantile values : but not used

# %%
# first_quart = []
# third_quart = []
# boundary = []
# ninetyfive_quant = []
# ninetynine_quant = []
# original_max = []


# for features in numeric_features:
#     first = data[features].quantile(0.25)
    
#     #first_quart.append(first)
    
#     third = data[features].quantile(.75)
#     #third_quart.append(third)

#     #Could change boundary if required from IQR x 1.5 to 3 or 5 as per the situation

#     boundary_val = round((third + (third - first) * 3),2)   
#     #print(boundary_val)
#     boundary.append(boundary_val)
#     ninetyfive_quant.append(data[features].quantile(.95))
#     ninetynine_quant.append(data[features].quantile(.99))
#     original_max.append(data[features].max())

# %%
#describe_df = data[numeric_features].describe().T

# %%
#describe_df["boundary"] = boundary

# %%
#describe_df["95_quant"] = ninetyfive_quant

# %%
#describe_df["99_quant"] = ninetynine_quant

# %%
#describe_df["original_max"] = original_max

# %%
#describe_df.T
# Out:
#               avg_no_of_peak_data_calls  \
# count                      99999.000000
# mean                           0.358165
# std                            4.065650
# min                            0.000000
# 25%                            0.000000
# 50%                            0.000000
# 75%                            0.000000
# max                          281.000000
# boundary                       0.000000
# 95_quant                       0.666667
# 99_quant                       7.000000
# original_max                 281.000000
#
#               avg_no_of_attempted_data_calls_placed  \
# count                                  99999.000000
# mean                                       0.870557
# std                                        9.053946
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        0.000000
# max                                      733.666667
# boundary                                   0.000000
# 95_quant                                   1.666667
# 99_quant                                  17.333333
# original_max                             733.666667
#
#               billing_adjusted_total_no_of_calls_over_the_life_of_the_cust  \
# count                                              99999.000000
# mean                                                2836.384514
# std                                                 3756.528545
# min                                                    0.000000
# 25%                                                  868.000000
# 50%                                                 1789.000000
# 75%                                                 3442.000000
# max                                                98705.000000
# boundary                                           11164.000000
# 95_quant                                            8592.100000
# 99_quant                                           17519.340000
# original_max                                       98705.000000
#
#               avg_rev_of_voice_overage  avg_no_of_completed_data_calls  \
# count                     99642.000000                    99999.000000
# mean                         13.295195                        0.774449
# std                          30.056211                        8.129884
# min                           0.000000                        0.000000
# 25%                           0.000000                        0.000000
# 50%                           0.682500                        0.000000
# 75%                          14.025000                        0.000000
# max                         896.087500                      559.333333
# boundary                     56.100000                        0.000000
# 95_quant                     64.349375                        1.333333
# 99_quant                    137.769250                       15.666667
# original_max                896.087500                      559.333333
#
#               avg_total_mthly_recurring_charge  \
# count                             99642.000000
# mean                                 46.178746
# std                                  23.623288
# min                                 -26.915000
# 25%                                  30.000000
# 50%                                  44.990000
# 75%                                  59.990000
# max                                 409.990000
# boundary                            149.960000
# 95_quant                             84.990000
# 99_quant                            118.029375
# original_max                        409.990000
#
#               avg_rounded_mins_of_cust_care_calls  \
# count                                99999.000000
# mean                                     4.666927
# std                                     12.762008
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      4.000000
# max                                    861.333333
# boundary                                16.000000
# 95_quant                                23.666667
# 99_quant                                55.333333
# original_max                           861.333333
#
#               total_no_of_calls_over_the_life_of_the_cust  \
# count                                        99999.000000
# mean                                          2877.159932
# std                                           3790.878155
# min                                              0.000000
# 25%                                            889.000000
# 50%                                           1822.000000
# 75%                                           3492.000000
# max                                          98874.000000
# boundary                                     11301.000000
# 95_quant                                      8701.100000
# 99_quant                                     17676.060000
# original_max                                 98874.000000
#
#               avg_no_of_unans_data_calls         churn  \
# count                       99999.000000  99999.000000
# mean                            0.029810      0.495615
# std                             0.496973      0.499983
# min                             0.000000      0.000000
# 25%                             0.000000      0.000000
# 50%                             0.000000      0.000000
# 75%                             0.000000      1.000000
# max                            81.666667      1.000000
# boundary                        0.000000      4.000000
# 95_quant                        0.000000      1.000000
# 99_quant                        0.666667      1.000000
# original_max                   81.666667      1.000000
#
#                            ...                 avg_no_of_completed_calls  \
# count                      ...                              99999.000000
# mean                       ...                                109.668073
# std                        ...                                119.594400
# min                        ...                                  0.000000
# 25%                        ...                                 28.666667
# 50%                        ...                                 76.000000
# 75%                        ...                                150.666667
# max                        ...                               1894.333333
# boundary                   ...                                516.670000
# 95_quant                   ...                                334.000000
# 99_quant                   ...                                561.333333
# original_max               ...                               1894.333333
#
#               no_of_days_of_current_equipment  \
# count                            99997.000000
# mean                               391.932238
# std                                256.484711
# min                                 -5.000000
# 25%                                212.000000
# 50%                                342.000000
# 75%                                530.000000
# max                               1823.000000
# boundary                          1484.000000
# 95_quant                           884.000000
# 99_quant                          1165.000000
# original_max                      1823.000000
#
#               avg_unrounded_mins_of_off_to_peak_data_calls  \
# count                                         99999.000000
# mean                                              1.135815
# std                                              17.768772
# min                                               0.000000
# 25%                                               0.000000
# 50%                                               0.000000
# 75%                                               0.000000
# max                                            2922.043333
# boundary                                          0.000000
# 95_quant                                          1.083333
# 99_quant                                         20.993667
# original_max                                   2922.043333
#
#               avg_mthly_rev_over_the_previous_three_months  \
# count                                         99999.000000
# mean                                             59.193242
# std                                              46.695654
# min                                               1.000000
# 25%                                              33.000000
# 50%                                              48.000000
# 75%                                              71.000000
# max                                            1593.000000
# boundary                                        185.000000
# 95_quant                                        139.000000
# 99_quant                                        238.000000
# original_max                                   1593.000000
#
#               avg_mthly_no_of_calls_over_the_previous_six_months  \
# count                                              97160.000000
# mean                                                 178.366828
# std                                                  182.724763
# min                                                    0.000000
# 25%                                                   59.000000
# 50%                                                  127.000000
# 75%                                                  237.000000
# max                                                 3256.000000
# boundary                                             771.000000
# 95_quant                                             514.000000
# 99_quant                                             865.000000
# original_max                                        3256.000000
#
#               avg_no_of_attempted_calls  avg_no_of_three_way_calls  \
# count                      99999.000000               99999.000000
# mean                         145.753683                   0.284723
# std                          159.348224                   1.092106
# min                            0.000000                   0.000000
# 25%                           38.333333                   0.000000
# 50%                          101.000000                   0.000000
# 75%                          199.666667                   0.333333
# max                         2289.000000                  66.000000
# boundary                     683.670000                   1.330000
# 95_quant                     445.000000                   1.333333
# 99_quant                     745.673333                   4.000000
# original_max                2289.000000                  66.000000
#
#               avg_unrounded_mins_of_completed_voice_calls  avg_overage_rev  \
# count                                        99999.000000     99642.000000
# mean                                           227.765797        13.559696
# std                                            264.404235        30.501008
# min                                              0.000000         0.000000
# 25%                                             49.053333         0.000000
# 50%                                            146.203333         1.000000
# 75%                                            309.478333        14.437500
# max                                           4514.453333      1102.400000
# boundary                                      1090.750000        57.750000
# 95_quant                                       743.564333        64.899750
# 99_quant                                      1218.236000       139.265450
# original_max                                  4514.453333      1102.400000
#
#               avg_no_of_call_forwarding_calls
# count                            99999.000000
# mean                                 0.011700
# std                                  0.547473
# min                                  0.000000
# 25%                                  0.000000
# 50%                                  0.000000
# 75%                                  0.000000
# max                                 81.333333
# boundary                             0.000000
# 95_quant                             0.000000
# 99_quant                             0.000000
# original_max                        81.333333
#
# [12 rows x 67 columns]

# %%
#describe_df_2 = describe_df.T

# %%
#describe_df_2.drop('churn', inplace = True, axis = 1)

# %%
# for feature in describe_df_2:
#     if describe_df_2[feature]['99_quant'] < describe_df_2[feature]['boundary']:
#         print(feature)

# %%
#describe_df_2.drop('current_handset_price', inplace = True, axis = 1)

# %%
# Creating a new dataset with 99 quantile for all outliers

# for feature in describe_df_2:
#     new_data = []
#     quant_99 = describe_df_2[feature]['99_quant']
    
#     for i in range(len(data)):
#         if data[feature][i] < quant_99:
#             new_data.append(data[feature][i])
#         else:
#             new_data.append(quant_99)
            
#     data[feature] = new_data

# %%
#data.describe()

# %% [markdown]
# ### Removing all missing values from the dataset at this stage to create

# %%
#data.shape

# %%
#quant99_data_without_NA_3 = data.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)

# %%
# quant99_data_without_NA_3 = quant99_data_without_NA_3.reset_index()
# quant99_data_without_NA_3.drop('index', axis = 1, inplace=True)

# %%
#quant99_data_without_NA_3.shape

# %%
#quant99_data_without_NA_3.to_csv('quant99_data_without_NA_3.csv')

# %% [markdown]
# ### Notebook 2 Ends Here
